# %% [markdown]
# <a href="https://colab.research.google.com/github/TitoRaffy/My-Programming-Fundamentals/blob/main/Vending%20Machine/Vending_Machine_trial__and_error(first_creation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Creating a Vending Machine using the Python programming language

# This is where the Menu Will start
# You get to choose whichever snack or drink you want
def order():
    totalFood=[0]
    print("   ---- Welcome to the vending machine ---- ")
    print(" <==========================================>   ")
    print("Here's the menu!")
    print("What would you like to order?\n")
    print("Food		Prices || Drinks	        Prices (AED)"),
    print("1. Ferrero	5      || 1. Pepsi		3.5	"),
    print("2. Hersheys	3      || 2. Mogumogu		2.5	"),
    print("3. Reeses	4      || 3. Water	        0.5	"),
    print("4. Snickers	2.5    || 4. Mountain Dew	3.5	"),
    print("5. Maltesers	2.5    || 5. Milk Tea		12	"),
    print("6. M&Ms	        3.5    || 6. Hot Choco		2.5	"),

# From here, you will select an item according to its product number
# You also have to choose between F or D for food or drinks (pretty much self explanatory)
    choice=(input("\nWant Snacks? Press F for the Food Section. Want Drinks? Press D for the Drinks Section: "))
    print("============================================================================================")
    if choice.lower() or choice.upper() == "f":
            print("You have selected Food")
            Prod_number = int(input("Please select the food according to its product number: "))       
            if Prod_number == 1:
                print("You have selected Ferrero")
                quantity = int(input("How many Ferrero would you like?:"))
                totalFood = float(quantity*5)
                print("Your total is", totalFood)
                money = float(input("Please enter the amount of money you would like to pay: "))
                change = money - totalFood
                if money < totalFood:
                    print("Not enough money inserted. Please insert additional funds.")
                else:
                    print("Your change is: " + str(change))
                    again = input("Would you like to order again? (yes/no)")
                    if again.lower() == "no":
                       break
           

        lif Prod_number == 2:
            print("You have selected Hersheys")
            print("Please enter the amount you want: ")
            quantity = int(input("How many Hersheys would you like? " ))
            totalFood = float(quantity*3)
            print("Your total is: ", totalFood)
            money = float(input("Please enter the amount of money you would like to pay: "))
            if money > totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
                yes_no = str(input("Would you want to order anything else? (yes/no): "))
                if yes_no.lower() == "no":
                    print("Thank you for ordering, Please come again!")

        elif Prod_number == 3:
            print("You have selected Reeses")
            print("Please enter the amount you want: ")
            quantity = int(input("How many Reeses would you like?" ))
            totalFood = float(quantity*4)
            print("Your total is: ", totalFood)
            money = float(input("Please enter the amount of money you would like to pay: "))
            if money > totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money < totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()
                
        elif Prod_number == 4:
            print("You have selected Snickers")
            print("Please enter the amount you want: ")
            quantity = int(input("How many Snickers would you like?" ))
            totalFood = float(quantity*2.5)
            print("Your total is: ", totalFood)
            money = float(input("Please enter the amount of money you would like to pay: "))
            if money > totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money < totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 5:
            print("You have selected Maltesers")
            print("Please enter the amount you want: ")
            quantity = int(input("How many Maltesers would you like?" ))
            totalFood = float(quantity*2.5)
            print("Your total is: ", totalFood)
            money = float(input("Please enter the amount of money you would like to pay: "))
            if money > totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money < totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 6:
            print("You have selected M&Ms")
            print("Please enter the amount you want: ")
            quantity = int(input("How many M&Ms would you like?" ))
            totalFood = float(quantity*3.5)
            print("Your total is: ", totalFood)
            money = float(input("Please enter the amount of money you would like to pay: "))
            if money > totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money < totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        else:
            print("Invalid input")
            return order()

    if choice == "D" or choice == "d":
        print("You have selected Drinks")
        Prod_number = int(input("Please select a drink according to its product number: "))

        if Prod_number == 1:
            print("You have selected Pepsi")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Pepsi would you like?" ))
            totalFood=float(quantity*3.5)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay:"))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 2:
            print("You have selected Mogumogu")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Mogumogu would you like? "))
            totalFood=float(quantity*2.5)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay: "))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 3:
            print("You have selected Water")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Water would you like? "))
            totalFood=float(quantity*.5)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay: "))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your food has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 4:
            print("You have selected Mountain Dew")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Mountain Dew would you like? "))
            totalFood=float(quantity*3.5)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay: "))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your drink has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 5:
            print("You have selected Milk Tea")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Milk Tea would you like? "))
            totalFood=float(quantity*12)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay: "))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your drink has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        elif Prod_number == 6:
            print("You have selected Hot Choco")
            print("Please enter the amount you want: ")
            quantity=int(input("How many Hot Choco would you like? "))
            totalFood=float(quantity*2.5)
            print("Your total is: ", totalFood)
            money=float(input("Please enter the amount of money you would like to pay: "))
            if money>totalFood:
                print("Your change is: ", money-totalFood, "AED")
                print("Your drink has been dispensed")
                print("----------------------------------")
            yes_no = str(input("Would you want to order anything else?: "))
            if choice == "No" or "no":
                print("Thank you for ordering, Please come again!")
            elif choice == "Yes" or "yes":
                return order()
            elif money<totalFood:
                print("You have not paid enough money")
                print("Please Try again")
                return order()

        else:
            print("Invalid input")
order()
